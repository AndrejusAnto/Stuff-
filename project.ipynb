# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Context
# # Imagine that you are a data analyst working for Spotify. Your team is responsible for content analysis, and in this quarter, you have decided to analyze Spotify's top hits and quantify what makes a hit song. Your team's product manager has many ideas and prepared a list of questions (requirements) that she wants you to get answers to. After reviewing the list of over 20 questions, you are not in a good mood - you'll have to work a couple of days to get all the answers. Luckily, a few days ago, an experienced data scientist working in your team queried the top 50 tracks for her machine learning project and agreed to share the data with you. This is a significant help - your SQL skills are not too sharp yet, and you don't yet know where to find all the relevant tables in your data warehouse. With this dataset, you are confident that you'll be able to answer all your PM's questions and maybe even look into some things that she didn't ask for.

# %% [markdown]
# # Provide clear explanations in your notebook. Your explanations should inform the reader what you are trying to achieve, what results you got, and what these results mean

# %% [markdown]
# #### Download the data from Spotify Top 50 Tracks of 2020 dataset (Kol kas negalima tiesiog siųsti per linką, nes kaggle reikalauja prisijungimo)
# #### Load the data using Pandas.

# %% [markdown]
# ## So first we load spotify top track csv file with pandas read_csv()

# %%
df = pd.read_csv("spotifytoptracks.csv")

# %% [markdown]
# ## and checking how data look by just running df

# %%
df
# Out:
#     Unnamed: 0           artist  \
# 0            0       The Weeknd
# 1            1      Tones And I
# 2            2      Roddy Ricch
# 3            3        SAINt JHN
# 4            4         Dua Lipa
# 5            5           DaBaby
# 6            6     Harry Styles
# 7            7            Powfu
# 8            8    Trevor Daniel
# 9            9    Lewis Capaldi
# 10          10          KAROL G
# 11          11   Arizona Zervas
# 12          12      Post Malone
# 13          13        Lil Mosey
# 14          14    Justin Bieber
# 15          15            Drake
# 16          16    Lewis Capaldi
# 17          17         Doja Cat
# 18          18         Maroon 5
# 19          19           Future
# 20          20        Jawsh 685
# 21          21     Harry Styles
# 22          22            Topic
# 23          23         24kGoldn
# 24          24    Billie Eilish
# 25          25     Shawn Mendes
# 26          26    Billie Eilish
# 27          27          Cardi B
# 28          28         Surfaces
# 29          29           Eminem
# 30          30    Justin Bieber
# 31          31         Dua Lipa
# 32          32              BTS
# 33          33            BENEE
# 34          34        Surf Mesa
# 35          35        Lady Gaga
# 36          36     Travis Scott
# 37          37      Post Malone
# 38          38           Maluma
# 39          39           Regard
# 40          40     Travis Scott
# 41          41  Black Eyed Peas
# 42          42       THE SCOTTS
# 43          43        Bad Bunny
# 44          44    Billie Eilish
# 45          45       Juice WRLD
# 46          46    Ariana Grande
# 47          47          JP Saxe
# 48          48         Dua Lipa
# 49          49     Travis Scott
#
#                                                 album  \
# 0                                         After Hours
# 1                                        Dance Monkey
# 2               Please Excuse Me For Being Antisocial
# 3                               Roses (Imanbek Remix)
# 4                                    Future Nostalgia
# 5                                    BLAME IT ON BABY
# 6                                           Fine Line
# 7                    death bed (coffee for your head)
# 8                                            Nicotine
# 9             Divinely Uninspired To A Hellish Extent
# 10                                               Tusa
# 11                                            ROXANNE
# 12                               Hollywood's Bleeding
# 13                                 Certified Hitmaker
# 14                                            Changes
# 15                               Dark Lane Demo Tapes
# 16  Divinely Uninspired To A Hellish Extent (Exten...
# 17                                           Hot Pink
# 18                                           Memories
# 19                                      High Off Life
# 20                   Savage Love (Laxed - Siren Beat)
# 21                                          Fine Line
# 22                                        Breaking Me
# 23                             Mood (feat. iann dior)
# 24                                everything i wanted
# 25                              Shawn Mendes (Deluxe)
# 26           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
#
# 34          0.001880    0.3930   0.3300  112.050       176547
# 35          0.000000    0.3230   0.6460  123.056       182200
# 36          0.000006    0.2100   0.0605   76.469       175721
# 37          0.000000    0.0685   0.9250   89.960       157560
# 38          0.000025    0.0626   0.5580  180.067       199112
# 39          0.000064    0.1060   0.8840  117.948       157606
# 40          0.000000    0.1490   0.4300  130.049       243837
# 41          0.001090    0.7920   0.6840  105.095       214935
# 42          0.000000    0.1570   0.2800  129.979       165978
# 43          0.000000    0.1070   0.6850   96.172       295177
# 44          0.000000    0.0950   0.1200  115.284       200186
# 45          0.000000    0.3400   0.2180   83.903       239836
# 46          0.000000    0.3820   0.5370  178.765       228482
# 47          0.000000    0.1090   0.6040   75.801       208687
# 48          0.000658    0.1020   0.7460  146.967       193829
# 49          0.000000    0.1240   0.4460  155.008       312820
#
#                                  genre
# 0                             R&B/Soul
# 1                    Alternative/Indie
# 2                          Hip-Hop/Rap
# 3                     Dance/Electronic
# 4                             Nu-disco
# 5                          Hip-Hop/Rap
# 6                                  Pop
# 7                          Hip-Hop/Rap
# 8              R&B/Hip-Hop alternative
# 9                    Alternative/Indie
# 10                                 Pop
# 11                         Hip-Hop/Rap
# 12                       Pop/Soft Rock
# 13                         Hip-Hop/Rap
# 14                                 Pop
# 15                         Hip-Hop/Rap
# 16                   Alternative/Indie
# 17                            R&B/Soul
# 18                                 Pop
# 19                         Hip-Hop/Rap
# 20                         Hip-Hop/Rap
# 21                                 Pop
# 22                    Dance/Electronic
# 23                             Pop rap
# 24                                 Pop
# 25                                 Pop
# 26                         Electro-pop
# 27                        Hip-Hop/Trap
# 28                         Electro-pop
# 29                         Hip-Hop/Rap
# 30                                 Pop
# 31                     Dance-pop/Disco
# 32                           Disco-pop
# 33                   Alternative/Indie
# 34                    Dance/Electronic
# 35                                 Pop
# 36                         Hip-Hop/Rap
# 37                Dreampop/Hip-Hop/R&B
# 38                                 Pop
# 39                    Dance/Electronic
# 40                         Hip-Hop/Rap
# 41                                 Pop
# 42                         Hip-Hop/Rap
# 43  Alternative/reggaeton/experimental
# 44                         Chamber pop
# 45                                 Pop
# 46                                 Pop
# 47                                 Pop
# 48                    Dance/Electronic
# 49                         Hip-Hop/Rap

# %% [markdown]
# ## We have a column named "Unnamed: 0" which maybe means ranking of song, but there is a mistake, because it starts from 0, so it seems that it would be mroe clear if 'Unnamed' is removed and index of dataframe would  to ranking. So using pandas drop():
# ## ["Unnamed: 0"] - we want to remove "Unnamed: 0" values
# ## axis="columns" - we set to remove from columns, not rows
# ## inplace=True - apply remove of "Unnamed: 0" in original dataframe and don't create new.

# %%
df.drop("Unnamed: 0", axis="columns", inplace=True)
df
# Out:
#              artist                                              album  \
# 0        The Weeknd                                        After Hours
# 1       Tones And I                                       Dance Monkey
# 2       Roddy Ricch              Please Excuse Me For Being Antisocial
# 3         SAINt JHN                              Roses (Imanbek Remix)
# 4          Dua Lipa                                   Future Nostalgia
# 5            DaBaby                                   BLAME IT ON BABY
# 6      Harry Styles                                          Fine Line
# 7             Powfu                   death bed (coffee for your head)
# 8     Trevor Daniel                                           Nicotine
# 9     Lewis Capaldi            Divinely Uninspired To A Hellish Extent
# 10          KAROL G                                               Tusa
# 11   Arizona Zervas                                            ROXANNE
# 12      Post Malone                               Hollywood's Bleeding
# 13        Lil Mosey                                 Certified Hitmaker
# 14    Justin Bieber                                            Changes
# 15            Drake                               Dark Lane Demo Tapes
# 16    Lewis Capaldi  Divinely Uninspired To A Hellish Extent (Exten...
# 17         Doja Cat                                           Hot Pink
# 18         Maroon 5                                           Memories
# 19           Future                                      High Off Life
# 20        Jawsh 685                   Savage Love (Laxed - Siren Beat)
# 21     Harry Styles                                          Fine Line
# 22            Topic                                        Breaking Me
# 23         24kGoldn                             Mood (feat. iann dior)
# 24    Billie Eilish                                everything i wanted
# 25     Shawn Mendes                              Shawn Mendes (Deluxe)
# 26    Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 27          Cardi B                    WAP (feat. Megan Thee Stallion)
# 28         Surfaces                                 Where the Light Is
# 29           Eminem                            Music To Be Murdered By
# 30    Justin Bieber                                            Changes
# 31         Dua Lipa                                   Future Nostalgia
# 32              BTS                         Dynamite (DayTime Version)
# 33            BENEE                                            Hey u x
# 34        Surf Mesa               ily (i love you baby) (feat. Emilee)
# 35        Lady Gaga                                         Chromatica
# 36     Travis Scott                                HIGHEST IN THE ROOM
# 37      Post Malone                               Hollywood's Bleeding
# 38           Maluma                                       PAPI JUANCHO
# 39           Regard                                            Ride It
# 40     Travis Scott                    Birds In The Trap Sing McKnight
# 41  Black Eyed Peas                                        Translation
# 42       THE SCOTTS                                         THE SCOTTS
# 43        Bad Bunny                                           YHLQMDLG
# 44    Billie Eilish                               lovely (with Khalid)
# 45       Juice WRLD                            Goodbye & Good Riddance
# 46    Ariana Grande                                       Stuck with U
# 47          JP Saxe     If the World Was Ending (feat. Julia Michaels)
# 48         Dua Lipa                                   Future Nostalgia
# 49     Travis Scott                                         ASTROWORLD
#
#                                         track_name                track_id  \
# 0                                  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1                                     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 2                                          The Box  0nbXyq5TXYPCO7pr3N8S4I
# 3                            Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5
# 4                                  Don't Start Now  3PfIrDoz19wz7qK7tYeu62
# 5                     ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog4
# 6                                 Watermelon Sugar  6UelLqGlWMcVH1E5c4H7lY
# 7                 death bed (coffee for your head)  7eJMfftS33KTjuF7lTsMCx
# 8                                          Falling  2rRJrJEo19S2J82BDsQ3F7
# 9                                Someone You Loved  7qEHsqek33rTcFNT9PFqLf
# 10                                            Tusa  7k4t7uLgtOxPwTpFmtJNTY
# 11                                         ROXANNE  696DnlkuDOXcMAnKlTgXXK
# 12                                         Circles  21jGcNKet2qwijlDFuPiPb
# 13                                 Blueberry Faygo  22LAwLoDA5b4AaGSkg6bKW
# 14                        Intentions (feat. Quavo)  4umIPjkehX1r7uhmGvXiSV
# 15                                    Toosie Slide  466cKvZn1j45IpxDdYZqdA
# 16                                   Before You Go  2gMXnyrvIjhVBUZwvLZDMP
# 17                                          Say So  3Dv1eDb0MEgF93GpLXlucZ
# 14          0.000000    0.1020   0.8740  147.986       212867
# 15          0.000003    0.1130   0.8450   81.604       247059
# 16          0.000000    0.0885   0.1830  111.881       215107
# 17          0.000004    0.0904   0.7860  110.962       237893
# 18          0.000000    0.0822   0.5750   91.019       189486
# 19          0.000000    0.1500   0.5370  142.053       237918
# 20          0.000000    0.2690   0.7610  150.076       171375
# 21          0.000007    0.1020   0.5690   99.048       207133
# 22          0.000000    0.1290   0.6640  122.031       166794
# 23          0.000000    0.2720   0.7560   90.989       140526
# 24          0.657000    0.1060   0.2430  120.006       245426
# 25          0.000000    0.0828   0.7490  116.967       190800
# 26          0.130000    0.1000   0.5620  135.128       194088
# 27          0.000000    0.0824   0.3570  133.073       187541
# 28          0.000000    0.0714   0.6940  112.022       158571
# 29          0.000000    0.2920   0.8290  165.995       210800
# 30          0.000000    0.1180   0.4970  145.842       208520
# 31          0.000001    0.3490   0.4670  113.013       221820
# 32          0.000000    0.0936   0.7370  114.044       199054
# 33          0.000209    0.1230   0.8410  128.978       223488
# 34          0.001880    0.3930   0.3300  112.050       176547
# 35          0.000000    0.3230   0.6460  123.056       182200
# 36          0.000006    0.2100   0.0605   76.469       175721
# 37          0.000000    0.0685   0.9250   89.960       157560
# 38          0.000025    0.0626   0.5580  180.067       199112
# 39          0.000064    0.1060   0.8840  117.948       157606
# 40          0.000000    0.1490   0.4300  130.049       243837
# 41          0.001090    0.7920   0.6840  105.095       214935
# 42          0.000000    0.1570   0.2800  129.979       165978
# 43          0.000000    0.1070   0.6850   96.172       295177
# 44          0.000000    0.0950   0.1200  115.284       200186
# 45          0.000000    0.3400   0.2180   83.903       239836
# 46          0.000000    0.3820   0.5370  178.765       228482
# 47          0.000000    0.1090   0.6040   75.801       208687
# 48          0.000658    0.1020   0.7460  146.967       193829
# 49          0.000000    0.1240   0.4460  155.008       312820
#
#                                  genre
# 0                             R&B/Soul
# 1                    Alternative/Indie
# 2                          Hip-Hop/Rap
# 3                     Dance/Electronic
# 4                             Nu-disco
# 5                          Hip-Hop/Rap
# 6                                  Pop
# 7                          Hip-Hop/Rap
# 8              R&B/Hip-Hop alternative
# 9                    Alternative/Indie
# 10                                 Pop
# 11                         Hip-Hop/Rap
# 12                       Pop/Soft Rock
# 13                         Hip-Hop/Rap
# 14                                 Pop
# 15                         Hip-Hop/Rap
# 16                   Alternative/Indie
# 17                            R&B/Soul
# 18                                 Pop
# 19                         Hip-Hop/Rap
# 20                         Hip-Hop/Rap
# 21                                 Pop
# 22                    Dance/Electronic
# 23                             Pop rap
# 24                                 Pop
# 25                                 Pop
# 26                         Electro-pop
# 27                        Hip-Hop/Trap
# 28                         Electro-pop
# 29                         Hip-Hop/Rap
# 30                                 Pop
# 31                     Dance-pop/Disco
# 32                           Disco-pop
# 33                   Alternative/Indie
# 34                    Dance/Electronic
# 35                                 Pop
# 36                         Hip-Hop/Rap
# 37                Dreampop/Hip-Hop/R&B
# 38                                 Pop
# 39                    Dance/Electronic
# 40                         Hip-Hop/Rap
# 41                                 Pop
# 42                         Hip-Hop/Rap
# 43  Alternative/reggaeton/experimental
# 44                         Chamber pop
# 45                                 Pop
# 46                                 Pop
# 47                                 Pop
# 48                    Dance/Electronic
# 49                         Hip-Hop/Rap

# %% [markdown]
# ## Now using df.index.name, we can set name for index as Rank and using simple addition of 1 to index make that index begin from 1 and ends as 50 and it would be as ranking numbers.

# %%
df.index.rename('Rank')
df.index += 1
df.index
# Out:
# RangeIndex(start=1, stop=51, step=1)

# %%
df
# Out:
#              artist                                              album  \
# 1        The Weeknd                                        After Hours
# 2       Tones And I                                       Dance Monkey
# 3       Roddy Ricch              Please Excuse Me For Being Antisocial
# 4         SAINt JHN                              Roses (Imanbek Remix)
# 5          Dua Lipa                                   Future Nostalgia
# 6            DaBaby                                   BLAME IT ON BABY
# 7      Harry Styles                                          Fine Line
# 8             Powfu                   death bed (coffee for your head)
# 9     Trevor Daniel                                           Nicotine
# 10    Lewis Capaldi            Divinely Uninspired To A Hellish Extent
# 11          KAROL G                                               Tusa
# 12   Arizona Zervas                                            ROXANNE
# 13      Post Malone                               Hollywood's Bleeding
# 14        Lil Mosey                                 Certified Hitmaker
# 15    Justin Bieber                                            Changes
# 16            Drake                               Dark Lane Demo Tapes
# 17    Lewis Capaldi  Divinely Uninspired To A Hellish Extent (Exten...
# 18         Doja Cat                                           Hot Pink
# 19         Maroon 5                                           Memories
# 20           Future                                      High Off Life
# 21        Jawsh 685                   Savage Love (Laxed - Siren Beat)
# 22     Harry Styles                                          Fine Line
# 23            Topic                                        Breaking Me
# 24         24kGoldn                             Mood (feat. iann dior)
# 25    Billie Eilish                                everything i wanted
# 26     Shawn Mendes                              Shawn Mendes (Deluxe)
# 27    Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 28          Cardi B                    WAP (feat. Megan Thee Stallion)
# 29         Surfaces                                 Where the Light Is
# 30           Eminem                            Music To Be Murdered By
# 31    Justin Bieber                                            Changes
# 32         Dua Lipa                                   Future Nostalgia
# 33              BTS                         Dynamite (DayTime Version)
# 34            BENEE                                            Hey u x
# 35        Surf Mesa               ily (i love you baby) (feat. Emilee)
# 36        Lady Gaga                                         Chromatica
# 37     Travis Scott                                HIGHEST IN THE ROOM
# 38      Post Malone                               Hollywood's Bleeding
# 39           Maluma                                       PAPI JUANCHO
# 40           Regard                                            Ride It
# 41     Travis Scott                    Birds In The Trap Sing McKnight
# 42  Black Eyed Peas                                        Translation
# 43       THE SCOTTS                                         THE SCOTTS
# 44        Bad Bunny                                           YHLQMDLG
# 45    Billie Eilish                               lovely (with Khalid)
# 46       Juice WRLD                            Goodbye & Good Riddance
# 47    Ariana Grande                                       Stuck with U
# 48          JP Saxe     If the World Was Ending (feat. Julia Michaels)
# 49         Dua Lipa                                   Future Nostalgia
# 50     Travis Scott                                         ASTROWORLD
#
#                                         track_name                track_id  \
# 1                                  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 2                                     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
# 3                                          The Box  0nbXyq5TXYPCO7pr3N8S4I
# 4                            Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5
# 5                                  Don't Start Now  3PfIrDoz19wz7qK7tYeu62
# 6                     ROCKSTAR (feat. Roddy Ricch)  7ytR5pFWmSjzHJIeQkgog
# 14                         Hip-Hop/Rap
# 15                                 Pop
# 16                         Hip-Hop/Rap
# 17                   Alternative/Indie
# 18                            R&B/Soul
# 19                                 Pop
# 20                         Hip-Hop/Rap
# 21                         Hip-Hop/Rap
# 22                                 Pop
# 23                    Dance/Electronic
# 24                             Pop rap
# 25                                 Pop
# 26                                 Pop
# 27                         Electro-pop
# 28                        Hip-Hop/Trap
# 29                         Electro-pop
# 30                         Hip-Hop/Rap
# 31                                 Pop
# 32                     Dance-pop/Disco
# 33                           Disco-pop
# 34                   Alternative/Indie
# 35                    Dance/Electronic
# 36                                 Pop
# 37                         Hip-Hop/Rap
# 38                Dreampop/Hip-Hop/R&B
# 39                                 Pop
# 40                    Dance/Electronic
# 41                         Hip-Hop/Rap
# 42                                 Pop
# 43                         Hip-Hop/Rap
# 44  Alternative/reggaeton/experimental
# 45                         Chamber pop
# 46                                 Pop
# 47                                 Pop
# 48                                 Pop
# 49                    Dance/Electronic
# 50                         Hip-Hop/Rap

# %% [markdown]
# ## For me lower case features don't look "right", so using columns.str.capitalize() we can make features capitalized

# %%
df.columns = df.columns.str.capitalize()
df
# Out:
#              Artist                                              Album  \
# 1        The Weeknd                                        After Hours
# 2       Tones And I                                       Dance Monkey
# 3       Roddy Ricch              Please Excuse Me For Being Antisocial
# 4         SAINt JHN                              Roses (Imanbek Remix)
# 5          Dua Lipa                                   Future Nostalgia
# 6            DaBaby                                   BLAME IT ON BABY
# 7      Harry Styles                                          Fine Line
# 8             Powfu                   death bed (coffee for your head)
# 9     Trevor Daniel                                           Nicotine
# 10    Lewis Capaldi            Divinely Uninspired To A Hellish Extent
# 11          KAROL G                                               Tusa
# 12   Arizona Zervas                                            ROXANNE
# 13      Post Malone                               Hollywood's Bleeding
# 14        Lil Mosey                                 Certified Hitmaker
# 15    Justin Bieber                                            Changes
# 16            Drake                               Dark Lane Demo Tapes
# 17    Lewis Capaldi  Divinely Uninspired To A Hellish Extent (Exten...
# 18         Doja Cat                                           Hot Pink
# 19         Maroon 5                                           Memories
# 20           Future                                      High Off Life
# 21        Jawsh 685                   Savage Love (Laxed - Siren Beat)
# 22     Harry Styles                                          Fine Line
# 23            Topic                                        Breaking Me
# 24         24kGoldn                             Mood (feat. iann dior)
# 25    Billie Eilish                                everything i wanted
# 26     Shawn Mendes                              Shawn Mendes (Deluxe)
# 27    Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 28          Cardi B                    WAP (feat. Megan Thee Stallion)
# 29         Surfaces                                 Where the Light Is
# 30           Eminem                            Music To Be Murdered By
# 31    Justin Bieber                                            Changes
# 32         Dua Lipa                                   Future Nostalgia
# 33              BTS                         Dynamite (DayTime Version)
# 34            BENEE                                            Hey u x
# 35        Surf Mesa               ily (i love you baby) (feat. Emilee)
# 36        Lady Gaga                                         Chromatica
# 37     Travis Scott                                HIGHEST IN THE ROOM
# 38      Post Malone                               Hollywood's Bleeding
# 39           Maluma                                       PAPI JUANCHO
# 40           Regard                                            Ride It
# 41     Travis Scott                    Birds In The Trap Sing McKnight
# 42  Black Eyed Peas                                        Translation
# 40          0.000064    0.1060   0.8840  117.948       157606
# 41          0.000000    0.1490   0.4300  130.049       243837
# 42          0.001090    0.7920   0.6840  105.095       214935
# 43          0.000000    0.1570   0.2800  129.979       165978
# 44          0.000000    0.1070   0.6850   96.172       295177
# 45          0.000000    0.0950   0.1200  115.284       200186
# 46          0.000000    0.3400   0.2180   83.903       239836
# 47          0.000000    0.3820   0.5370  178.765       228482
# 48          0.000000    0.1090   0.6040   75.801       208687
# 49          0.000658    0.1020   0.7460  146.967       193829
# 50          0.000000    0.1240   0.4460  155.008       312820
#
#                                  Genre
# 1                             R&B/Soul
# 2                    Alternative/Indie
# 3                          Hip-Hop/Rap
# 4                     Dance/Electronic
# 5                             Nu-disco
# 6                          Hip-Hop/Rap
# 7                                  Pop
# 8                          Hip-Hop/Rap
# 9              R&B/Hip-Hop alternative
# 10                   Alternative/Indie
# 11                                 Pop
# 12                         Hip-Hop/Rap
# 13                       Pop/Soft Rock
# 14                         Hip-Hop/Rap
# 15                                 Pop
# 16                         Hip-Hop/Rap
# 17                   Alternative/Indie
# 18                            R&B/Soul
# 19                                 Pop
# 20                         Hip-Hop/Rap
# 21                         Hip-Hop/Rap
# 22                                 Pop
# 23                    Dance/Electronic
# 24                             Pop rap
# 25                                 Pop
# 26                                 Pop
# 27                         Electro-pop
# 28                        Hip-Hop/Trap
# 29                         Electro-pop
# 30                         Hip-Hop/Rap
# 31                                 Pop
# 32                     Dance-pop/Disco
# 33                           Disco-pop
# 34                   Alternative/Indie
# 35                    Dance/Electronic
# 36                                 Pop
# 37                         Hip-Hop/Rap
# 38                Dreampop/Hip-Hop/R&B
# 39                                 Pop
# 40                    Dance/Electronic
# 41                         Hip-Hop/Rap
# 42                                 Pop
# 43                         Hip-Hop/Rap
# 44  Alternative/reggaeton/experimental
# 45                         Chamber pop
# 46                                 Pop
# 47                                 Pop
# 48                                 Pop
# 49                    Dance/Electronic
# 50                         Hip-Hop/Rap

# %% [markdown]
# ## Perform data cleaning by:

# %% [markdown]
# ##### Handling missing values.

# %% [markdown]
# ## Now using pandas isnull() and any(), we can check if at least one value is missing

# %%
df.isnull().any()
# Out:
# Artist              False
# Album               False
# Track_name          False
# Track_id            False
# Energy              False
# Danceability        False
# Key                 False
# Loudness            False
# Acousticness        False
# Speechiness         False
# Instrumentalness    False
# Liveness            False
# Valence             False
# Tempo               False
# Duration_ms         False
# Genre               False
# dtype: bool

# %% [markdown]
# ## We have "false" for every a feature that means that there is no missing values and we don't need to use pandas dropna() to remove rows or features.

# %% [markdown]
# ##### Removing duplicate samples and features.

# %% [markdown]
# ## With drop_duplicates() we can check if there is the duplicate info. Checking truthness by comparing original dataframe with returned dataframe by drop_duplicates() and using all() we can find if all elements are the same and they are because returned value is True.

# %%
all(df == df.drop_duplicates())
# Out:
# True

# %% [markdown]
# #### Treating the outliers

# %% [markdown]
# ## Dataframe have 'Track_id' feature which is just specific spotify info and we don't need it so using pandas drop():
# ## ["Track_id"] - we want to remove "Track_id" values
# ## axis="columns" - we set to remove from columns, not rows
# ## inplace=True - apply remove of "Track_id" in original dataframe and doesn't create new.

# %%
df.drop(["Track_id"], axis="columns", inplace=True)
df
# Out:
#              Artist                                              Album  \
# 1        The Weeknd                                        After Hours
# 2       Tones And I                                       Dance Monkey
# 3       Roddy Ricch              Please Excuse Me For Being Antisocial
# 4         SAINt JHN                              Roses (Imanbek Remix)
# 5          Dua Lipa                                   Future Nostalgia
# 6            DaBaby                                   BLAME IT ON BABY
# 7      Harry Styles                                          Fine Line
# 8             Powfu                   death bed (coffee for your head)
# 9     Trevor Daniel                                           Nicotine
# 10    Lewis Capaldi            Divinely Uninspired To A Hellish Extent
# 11          KAROL G                                               Tusa
# 12   Arizona Zervas                                            ROXANNE
# 13      Post Malone                               Hollywood's Bleeding
# 14        Lil Mosey                                 Certified Hitmaker
# 15    Justin Bieber                                            Changes
# 16            Drake                               Dark Lane Demo Tapes
# 17    Lewis Capaldi  Divinely Uninspired To A Hellish Extent (Exten...
# 18         Doja Cat                                           Hot Pink
# 19         Maroon 5                                           Memories
# 20           Future                                      High Off Life
# 21        Jawsh 685                   Savage Love (Laxed - Siren Beat)
# 22     Harry Styles                                          Fine Line
# 23            Topic                                        Breaking Me
# 24         24kGoldn                             Mood (feat. iann dior)
# 25    Billie Eilish                                everything i wanted
# 26     Shawn Mendes                              Shawn Mendes (Deluxe)
# 27    Billie Eilish           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?
# 28          Cardi B                    WAP (feat. Megan Thee Stallion)
# 29         Surfaces                                 Where the Light Is
# 30           Eminem                            Music To Be Murdered By
# 31    Justin Bieber                                            Changes
# 32         Dua Lipa                                   Future Nostalgia
# 33              BTS                         Dynamite (DayTime Version)
# 34            BENEE                                            Hey u x
# 35        Surf Mesa               ily (i love you baby) (feat. Emilee)
# 36        Lady Gaga                                         Chromatica
# 37     Travis Scott                                HIGHEST IN THE ROOM
# 38      Post Malone                               Hollywood's Bleeding
# 39           Maluma                                       PAPI JUANCHO
# 40           Regard                                            Ride It
# 41     Travis Scott                    Birds In The Trap Sing McKnight
# 42  Black Eyed Peas                                        Translation
# 43       THE SCOTTS                                         THE SCOTTS
# 44        Bad Bunny                                           YHLQMDLG
# 45    Billie Eilish                               lovely (with Khalid)
# 46       Juice WRLD                            Goodbye & Good Riddance
# 47    Ariana Grande                                       Stuck with U
# 48          JP Saxe     If the World Was Ending (feat. Julia Michaels)
# 49         Dua Lipa                                   Future Nostalgia
# 50     Travis Scott                                         ASTROWORLD
#
#                                         Track_name  Energy  Danceability  Key  \
# 1                                  Blinding Lights   0.730         0.514    1
# 2                                     Dance Monkey   0.593         0.825    6
# 3                                          The Box   0.586         0.896   10
# 4                            Roses - Imanbek Remix   0.721         0.785    8
# 5                                  Don't Start Now   0.793         0.793   11
# 6                     ROCKSTAR (feat. Roddy Ricch)   0.690         0.746   11
# 7                                 Watermelon Sugar   0.816         0.548    0
# 8                 death bed (coffee for your head)   0.431         0.726    8
# 9                                          Falling   0.430         0.784   10
# 10                               Someone You Loved   0.405         0.501    1
# 11                                            Tusa   0.715         0.803    2
# 12                                         ROXANNE   0.601         0.621    6
# 13                                         Circles   0.762         0.695    0
# 14                                 Blueberry Faygo   0.554         0.774    0
# 15                        Intentions (feat. Quavo)   0.546         0.806    9
# 16                                    Toosie Slide   0.490         0.830    1
# 17                                   Before You Go   0.575         0.459    3
# 18                                          Say So   0.673         0.787   11
# 19                                        Memories   0.320         0.764   11
# 20                      Life Is Good (feat. Drake)   0.574         0.795    2
# 21                Savage Love (Laxed - Siren Beat)   0.481         0.767    0
# 22                                       Adore You   0.771         0.676    8
# 23                                     Breaking Me   0.720         0.789    8
# 24                          Mood (feat. iann dior)   0.722         0.700    7
# 25                             everything i wanted   0.225         0.704    6
# 26                                        Señorita   0.548         0.759    9
# 27                                         bad guy   0.425         0.701    7
# 28                 WAP (feat. Megan Thee Stallion)   0.454         0.935    1
# 29                                     Sunday Best   0.525         0.878    5
# 30                     Godzilla (feat. Juice WRLD)   0.745         0.808   10
# 31                                           Yummy   0.506         0.676    9
# 32                                  Break My Heart   0.729         0.730    4
# 33                                        Dynamite   0.765         0.746    6
# 34                Supalonely (feat. Gus Dapperton)   0.631         0.862    7
# 35            ily (i love you baby) (feat. Emilee)   0.774         0.674   11
# 36                 Rain On Me (with Ariana Grande)   0.855         0.672    9
# 37                             HIGHEST IN THE ROOM   0.427         0.598    7
# 38   Sunflower - Spider-Man: Into the Spider-Verse   0.522         0.755    2
# 39                                           Hawái   0.727         0.783    6
# 40                                         Ride It   0.751         0.880    7
# 41                                      goosebumps   0.728         0.841    7
# 42                       RITMO (Bad Boys For Life)   0.704         0.723   10
# 43                                      THE SCOTTS   0.537         0.716    0
# 44                                         Safaera   0.829         0.607    2
# 45                            lovely (with Khalid)   0.296         0.351    4
# 46                                    Lucid Dreams   0.566         0.511    6
# 47               Stuck with U (with Justin Bieber)   0.450         0.597    8
# 48  If the World Was Ending - feat. Julia Michaels   0.473         0.464    1
# 49                                        Physical   0.844         0.647    0
# 50                                      SICKO MODE   0.730         0.834    8
#
#     Loudness  Acousticness  Speechiness  Instrumentalness  Liveness  Valence  \
# 1     -5.934       0.00146       0.0598          0.000095    0.0897   0.3340
# 2     -6.401       0.68800       0.0988          0.000161    0.1700   0.5400
# 3     -6.687       0.10400       0.0559          0.000000    0.7900   0.6420
# 4     -5.457       0.01490       0.0506          0.004320    0.2850   0.8940
# 5     -4.521       0.01230       0.0830          0.000000    0.0951   0.6790
# 6     -7.956       0.24700       0.1640          0.000000    0.1010   0.4970
# 7     -4.209       0.12200       0.0465          0.000000    0.3350   0.5570
# 8     -8.765       0.73100       0.1350          0.000000    0.6960   0.3480
# 9     -8.756       0.12300       0.0364          0.000000    0.0887   0.2360
# 10    -5.679       0.75100       0.0319          0.000000    0.1050   0.4460
# 11    -3.280       0.29500       0.2980          0.000134    0.0574   0.5740
# 12    -5.616       0.05220       0.1480          0.000000    0.4600   0.4570
# 13    -3.497       0.19200       0.0395          0.002440    0.0863   0.5530
# 14    -7.909       0.20700       0.0383          0.000000    0.1320   0.3490
# 15    -6.637       0.30000       0.0575          0.000000    0.1020   0.8740
# 17  111.881       215107                   Alternative/Indie
# 18  110.962       237893                            R&B/Soul
# 19   91.019       189486                                 Pop
# 20  142.053       237918                         Hip-Hop/Rap
# 21  150.076       171375                         Hip-Hop/Rap
# 22   99.048       207133                                 Pop
# 23  122.031       166794                    Dance/Electronic
# 24   90.989       140526                             Pop rap
# 25  120.006       245426                                 Pop
# 26  116.967       190800                                 Pop
# 27  135.128       194088                         Electro-pop
# 28  133.073       187541                        Hip-Hop/Trap
# 29  112.022       158571                         Electro-pop
# 30  165.995       210800                         Hip-Hop/Rap
# 31  145.842       208520                                 Pop
# 32  113.013       221820                     Dance-pop/Disco
# 33  114.044       199054                           Disco-pop
# 34  128.978       223488                   Alternative/Indie
# 35  112.050       176547                    Dance/Electronic
# 36  123.056       182200                                 Pop
# 37   76.469       175721                         Hip-Hop/Rap
# 38   89.960       157560                Dreampop/Hip-Hop/R&B
# 39  180.067       199112                                 Pop
# 40  117.948       157606                    Dance/Electronic
# 41  130.049       243837                         Hip-Hop/Rap
# 42  105.095       214935                                 Pop
# 43  129.979       165978                         Hip-Hop/Rap
# 44   96.172       295177  Alternative/reggaeton/experimental
# 45  115.284       200186                         Chamber pop
# 46   83.903       239836                                 Pop
# 47  178.765       228482                                 Pop
# 48   75.801       208687                                 Pop
# 49  146.967       193829                    Dance/Electronic
# 50  155.008       312820                         Hip-Hop/Rap

# %%
df.describe()
# Out:
#           Energy  Danceability        Key   Loudness  Acousticness  \
# count  50.000000     50.000000  50.000000  50.000000     50.000000
# mean    0.609300      0.716720   5.720000  -6.225900      0.256206
# std     0.154348      0.124975   3.709007   2.349744      0.265250
# min     0.225000      0.351000   0.000000 -14.454000      0.001460
# 25%     0.494000      0.672500   2.000000  -7.552500      0.052800
# 50%     0.597000      0.746000   6.500000  -5.991500      0.188500
# 75%     0.729750      0.794500   8.750000  -4.285500      0.298750
# max     0.855000      0.935000  11.000000  -3.280000      0.934000
#
#        Speechiness  Instrumentalness   Liveness    Valence       Tempo  \
# count    50.000000         50.000000  50.000000  50.000000   50.000000
# mean      0.124158          0.015962   0.196552   0.555710  119.690460
# std       0.116836          0.094312   0.176610   0.216386   25.414778
# min       0.029000          0.000000   0.057400   0.060500   75.801000
# 25%       0.048325          0.000000   0.093950   0.434000   99.557250
# 50%       0.070050          0.000000   0.111000   0.560000  116.969000
# 75%       0.155500          0.000020   0.271250   0.726250  132.317000
# max       0.487000          0.657000   0.792000   0.925000  180.067000
#
#          Duration_ms
# count      50.000000
# mean   199955.360000
# std     33996.122488
# min    140526.000000
# 25%    175845.500000
# 50%    197853.500000
# 75%    215064.000000
# max    312820.000000

# %% [markdown]
# ### Perform exploratory data analysis. Your analysis should provide answers to these questions:

# %% [markdown]
# ## Using python unpacking, we can save pandas shape info to separate variables and print it

# %% [markdown]
# #### How many observations are there in this dataset?

# %%
observations, features = df.shape
print(f"Number of observations = {observations}")
# Out:
# Number of observations = 50

# %% [markdown]
# #### How many features this dataset has?

# %%
print(f"Number of features = {features}")
# Out:
# Number of features = 15

# %% [markdown]
# ## With pandas select_dtypes() we can filter the types we want and non-numeric values have type 'object', so:
# ## include=object - we select 'object' type
# ## .columns.values - we select column values to be filtered as 'object' type

# %%
not_numeric = df.select_dtypes(include=object).columns.values
print(not_numeric)
# Out:
# ['Artist' 'Album' 'Track_name' 'Genre']

# %% [markdown]
# ## Because only 'Track_name' can have one unique value so categorcial features are 'Artist' 'Album' and 'Genre', so using numpy delete() we can delete  value at specific location and with np.where we set condition that a value would be equal to 'Track_name'

# %% [markdown]
# #### Which of the features are categorical?

# %%
categorical = np.delete(not_numeric, np.where(not_numeric == "Track_name"))
print(categorical)
# Out:
# ['Artist' 'Album' 'Genre']

# %% [markdown]
# #### Which of the features are numeric?

# %% [markdown]
# ## as it was for categorical values we can use 'include=np.number' to find columns which have numeric values

# %%
print(df.select_dtypes(include=np.number).columns.values)
# Out:
# ['Energy' 'Danceability' 'Key' 'Loudness' 'Acousticness' 'Speechiness'
#  'Instrumentalness' 'Liveness' 'Valence' 'Tempo' 'Duration_ms']

# %% [markdown]
# ## Using pandas column selection by ["Artist"] and value_counts() we can count how many time artist appear in top songs list and then using filterting more_than_1[more_than_1 > 1] aka boolean mask we can find artists with more then 1 track.

# %% [markdown]
# #### Are there any artists that have more than 1 popular track? If yes, which and how many?

# %%
artist_more_than_1 = df['Artist'].value_counts()
artist_more_than_1[artist_more_than_1 > 1]
# Out:
# Billie Eilish    3
# Dua Lipa         3
# Travis Scott     3
# Justin Bieber    2
# Harry Styles     2
# Lewis Capaldi    2
# Post Malone      2
# Name: Artist, dtype: int64

# %% [markdown]
# ## As we can see, there 3 artist with 3 tracks, so using max() we can find maximal value and using filtering:
# ## more_than_1==more_than_1.max() we can find all artists who have maximal value of tracks

# %% [markdown]
# #### Who was the most popular artist?!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
artist_more_than_1[artist_more_than_1==artist_more_than_1.max()]
# Out:
# Billie Eilish    3
# Dua Lipa         3
# Travis Scott     3
# Name: Artist, dtype: int64

# %% [markdown]
# ## Using pandas unique() we can find unique artists and df['Artist'].unique() is numpy array so we can use 'size' to find total number of unique artists

# %% [markdown]
# #### How many artists in total have their songs in the top 50?

# %%
df['Artist'].unique().size
# Out:
# 40

# %% [markdown]
# ## We do the same as for artist to find albums which have more than 1 track

# %% [markdown]
# #### Are there any albums that have more than 1 popular track? If yes, which and how many?

# %%
album_more_than_1 = df['Album'].value_counts()
album_more_than_1[album_more_than_1 > 1]
# Out:
# Future Nostalgia        3
# Hollywood's Bleeding    2
# Fine Line               2
# Changes                 2
# Name: Album, dtype: int64

# %% [markdown]
# #### How many albums in total have their songs in the top 50?

# %%
df['Album'].unique().size
# Out:
# 45

# %% [markdown]
# ## Using pandas .loc we can access rows and columns by labels or boolean arrays and that's what we do here:
# ## df['Danceability'] > 0.7 - boolean array for filtering out rows where Danceability > 0.7
# ## 'Track_name' - here we select the column 'Track_name'.

# %% [markdown]
# #### Which tracks have a danceability score above 0.7?

# %%
df.loc[df['Danceability'] > 0.7, 'Track_name']
# Out:
# 2                                      Dance Monkey
# 3                                           The Box
# 4                             Roses - Imanbek Remix
# 5                                   Don't Start Now
# 6                      ROCKSTAR (feat. Roddy Ricch)
# 8                  death bed (coffee for your head)
# 9                                           Falling
# 11                                             Tusa
# 14                                  Blueberry Faygo
# 15                         Intentions (feat. Quavo)
# 16                                     Toosie Slide
# 18                                           Say So
# 19                                         Memories
# 20                       Life Is Good (feat. Drake)
# 21                 Savage Love (Laxed - Siren Beat)
# 23                                      Breaking Me
# 25                              everything i wanted
# 26                                         Señorita
# 27                                          bad guy
# 28                  WAP (feat. Megan Thee Stallion)
# 29                                      Sunday Best
# 30                      Godzilla (feat. Juice WRLD)
# 32                                   Break My Heart
# 33                                         Dynamite
# 34                 Supalonely (feat. Gus Dapperton)
# 38    Sunflower - Spider-Man: Into the Spider-Verse
# 39                                            Hawái
# 40                                          Ride It
# 41                                       goosebumps
# 42                        RITMO (Bad Boys For Life)
# 43                                       THE SCOTTS
# 50                                       SICKO MODE
# Name: Track_name, dtype: object

# %% [markdown]
# #### Which tracks have a danceability score below 0.4?

# %%
df.loc[df['Danceability'] < 0.4, 'Track_name']
# Out:
# 45    lovely (with Khalid)
# Name: Track_name, dtype: object

# %% [markdown]
# #### Which tracks have their loudness above -5?

# %%
df.loc[df['Loudness'] > -5, 'Track_name']
# Out:
# 5                                   Don't Start Now
# 7                                  Watermelon Sugar
# 11                                             Tusa
# 13                                          Circles
# 17                                    Before You Go
# 18                                           Say So
# 22                                        Adore You
# 24                           Mood (feat. iann dior)
# 32                                   Break My Heart
# 33                                         Dynamite
# 34                 Supalonely (feat. Gus Dapperton)
# 36                  Rain On Me (with Ariana Grande)
# 38    Sunflower - Spider-Man: Into the Spider-Verse
# 39                                            Hawái
# 40                                          Ride It
# 41                                       goosebumps
# 44                                          Safaera
# 49                                         Physical
# 50                                       SICKO MODE
# Name: Track_name, dtype: object

# %% [markdown]
# #### Which tracks have their loudness below -8?

# %%
df.loc[df['Loudness'] < -8, 'Track_name']
# Out:
# 8                   death bed (coffee for your head)
# 9                                            Falling
# 16                                      Toosie Slide
# 21                  Savage Love (Laxed - Siren Beat)
# 25                               everything i wanted
# 27                                           bad guy
# 37                               HIGHEST IN THE ROOM
# 45                              lovely (with Khalid)
# 48    If the World Was Ending - feat. Julia Michaels
# Name: Track_name, dtype: object

# %% [markdown]
# ## With idxmax() we can find index of max value aka longest track, so with df['Duration_ms'] select Duration_ms column, idxmax() finds longest track index and then we select row value of track by index applied to df["Track_name"].

# %% [markdown]
# #### Which track is the longest?

# %%
longest_track = df["Track_name"][df['Duration_ms'].idxmax()]
artist = df["Artist"][df['Duration_ms'].idxmax()]
print(f"{longest_track} by {artist}")
# Out:
# SICKO MODE by Travis Scott

# %% [markdown]
# ## To find shortest track instead of idxmax() we use idxmin()

# %% [markdown]
# #### Which track is the shortest?

# %%
shortest_track = df["Track_name"][df['Duration_ms'].idxmin()]
artist = df["Artist"][df['Duration_ms'].idxmin()]
print(f"{shortest_track} by {artist}")
# Out:
# Mood (feat. iann dior) by 24kGoldn

# %% [markdown]
# ## df['Genre'] selects 'Genre' column, value_counts() counts occurrence of every genre and idxmax find index of row (because default axis=0=row) with highest count

# %% [markdown]
# #### Which genre is the most popular?

# %%
most_popular_genre = df['Genre'].value_counts().idxmax()
most_popular_genre_number = df['Genre'].value_counts().max()
print(f"{most_popular_genre} {most_popular_genre_number}")
# Out:
# Pop 14

# %% [markdown]
# ## with df['Genre'].value_counts() we count genres occurrences, then we create filter variable with 'genres == 1' and apply it to genres count dataframe.

# %% [markdown]
# #### Which genres have just one song on the top 50?

# %%
genres = df['Genre'].value_counts()
one_song = genres == 1
genres[one_song]
# Out:
# Nu-disco                              1
# R&B/Hip-Hop alternative               1
# Pop/Soft Rock                         1
# Pop rap                               1
# Hip-Hop/Trap                          1
# Dance-pop/Disco                       1
# Disco-pop                             1
# Dreampop/Hip-Hop/R&B                  1
# Alternative/reggaeton/experimental    1
# Chamber pop                           1
# Name: Genre, dtype: int64

# %% [markdown]
# ## Again using unique() and numpy size, we can find total number of genres.

# %% [markdown]
# #### How many genres in total are represented in the top 50?

# %%
df['Genre'].unique().size
# Out:
# 16

# %% [markdown]
# ## To find correlation between features, we can use df.corr() and using numeric_only=True option we can automaticlly apply to numeric features.

# %%
df.corr(numeric_only=True)
# Out:
#                     Energy  Danceability       Key  Loudness  Acousticness  \
# Energy            1.000000      0.152552  0.062428  0.791640     -0.682479
# Danceability      0.152552      1.000000  0.285036  0.167147     -0.359135
# Key               0.062428      0.285036  1.000000 -0.009178     -0.113394
# Loudness          0.791640      0.167147 -0.009178  1.000000     -0.498695
# Acousticness     -0.682479     -0.359135 -0.113394 -0.498695      1.000000
# Speechiness       0.074267      0.226148 -0.094965 -0.021693     -0.135392
# Instrumentalness -0.385515     -0.017706  0.020802 -0.553735      0.352184
# Liveness          0.069487     -0.006648  0.278672 -0.069939     -0.128384
# Valence           0.393453      0.479953  0.120007  0.406772     -0.243192
# Tempo             0.075191      0.168956  0.080475  0.102097     -0.241119
# Duration_ms       0.081971     -0.033763 -0.003345  0.064130     -0.010988
#
#                   Speechiness  Instrumentalness  Liveness   Valence     Tempo  \
# Energy               0.074267         -0.385515  0.069487  0.393453  0.075191
# Danceability         0.226148         -0.017706 -0.006648  0.479953  0.168956
# Key                 -0.094965          0.020802  0.278672  0.120007  0.080475
# Loudness            -0.021693         -0.553735 -0.069939  0.406772  0.102097
# Acousticness        -0.135392          0.352184 -0.128384 -0.243192 -0.241119
# Speechiness          1.000000          0.028948 -0.142957  0.053867  0.215504
# Instrumentalness     0.028948          1.000000 -0.087034 -0.203283  0.018853
# Liveness            -0.142957         -0.087034  1.000000 -0.033366  0.025457
# Valence              0.053867         -0.203283 -0.033366  1.000000  0.045089
# Tempo                0.215504          0.018853  0.025457  0.045089  1.000000
# Duration_ms          0.366976          0.184709 -0.090188 -0.039794  0.130328
#
#                   Duration_ms
# Energy               0.081971
# Danceability        -0.033763
# Key                 -0.003345
# Loudness             0.064130
# Acousticness        -0.010988
# Speechiness          0.366976
# Instrumentalness     0.184709
# Liveness            -0.090188
# Valence             -0.039794
# Tempo                0.130328
# Duration_ms          1.000000

# %% [markdown]
# ## Now we can save corrleations to variable 'corrleations', unstack it correlations.unstack() then using with filters (correlations > .75) set that only filter out correlation values higher then .75 for strongly positive correlation and with (correlations != 1) don't enclude feature correlation with it self.

# %% [markdown]
# #### Which features are strongly positively correlated?

# %%
correlations = df.corr(numeric_only=True)
correlations = correlations.unstack()
correlations[(correlations > .75) & (correlations != 1)]
# Out:
# Energy    Loudness    0.79164
# Loudness  Energy      0.79164
# dtype: float64

# %% [markdown]
# ## same as for finding "strongly positively correlated", here we set correlation value -0.75 for 'strongly negitively correlated'

# %% [markdown]
# #### Which features are strongly negatively correlated?

# %%
correlations = df.corr(numeric_only=True)
correlations = correlations.unstack()
correlations[(correlations < -0.75) & (correlations != 1)]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## for not correlated feature we can set a value between -0.1 and 0.1, but we don't need to have 2 separate filter, with abs() we can find absolute values and just find lower absolute values than 0.1.

# %% [markdown]
# #### Which features are not correlated?

# %%
correlations = df.corr(numeric_only=True)
correlations = correlations.unstack()
correlations[(abs(correlations) < 0.1) & (correlations != 1)]
# Out:
# Energy            Key                 0.062428
#                   Speechiness         0.074267
#                   Liveness            0.069487
#                   Tempo               0.075191
#                   Duration_ms         0.081971
# Danceability      Instrumentalness   -0.017706
#                   Liveness           -0.006648
#                   Duration_ms        -0.033763
# Key               Energy              0.062428
#                   Loudness           -0.009178
#                   Speechiness        -0.094965
#                   Instrumentalness    0.020802
#                   Tempo               0.080475
#                   Duration_ms        -0.003345
# Loudness          Key                -0.009178
#                   Speechiness        -0.021693
#                   Liveness           -0.069939
#                   Duration_ms         0.064130
# Acousticness      Duration_ms        -0.010988
# Speechiness       Energy              0.074267
#                   Key                -0.094965
#                   Loudness           -0.021693
#                   Instrumentalness    0.028948
#                   Valence             0.053867
# Instrumentalness  Danceability       -0.017706
#                   Key                 0.020802
#                   Speechiness         0.028948
#                   Liveness           -0.087034
#                   Tempo               0.018853
# Liveness          Energy              0.069487
#                   Danceability       -0.006648
#                   Loudness           -0.069939
#                   Instrumentalness   -0.087034
#                   Valence            -0.033366
#                   Tempo               0.025457
#                   Duration_ms        -0.090188
# Valence           Speechiness         0.053867
#                   Liveness           -0.033366
#                   Tempo               0.045089
#                   Duration_ms        -0.039794
# Tempo             Energy              0.075191
#                   Key                 0.080475
#                   Instrumentalness    0.018853
#                   Liveness            0.025457
#                   Valence             0.045089
# Duration_ms       Energy              0.081971
#                   Danceability       -0.033763
#                   Key                -0.003345
#                   Loudness            0.064130
#                   Acousticness       -0.010988
#                   Liveness           -0.090188
#                   Valence            -0.039794
# dtype: float64

# %% [markdown]
# ## Using pandas groupby() we can group colmuns by other columns. Here we set variables that we will use later: 'metric' as metric we want to find informaction about and 'gernes' as list of genres we are interested in. So:
# ## df.groupy("Genre") - we are grouping by "Genre"
# ## [metric] - we set column for which value we want to group.
# ## mean() - find mean of grouped colmuns scores.
# ## [genres] - filter out genres we are intrested in.
# ## sort_values() - sort mean values, default sorting is ascending.

# %% [markdown]
# #### How does the danceability score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?

# %%
metric = 'Danceability'
genres = ["Pop", "Hip-Hop/Rap", "Dance/Electronic", "Alternative/Indie"]          
df.groupby("Genre")[metric].mean()[genres].sort_values()
# Out:
# Genre
# Alternative/Indie    0.661750
# Pop                  0.677571
# Dance/Electronic     0.755000
# Hip-Hop/Rap          0.765538
# Name: Danceability, dtype: float64

# %% [markdown]
# ## Here we just need to change metric to 'Loudness'.

# %% [markdown]
# #### How does the loudness score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?

# %%
metric = 'Loudness'
df.groupby("Genre")[metric].mean()[genres].sort_values()
# Out:
# Genre
# Hip-Hop/Rap         -6.917846
# Pop                 -6.460357
# Alternative/Indie   -5.421000
# Dance/Electronic    -5.338000
# Name: Loudness, dtype: float64

# %% [markdown]
# ## Here we just need to change metric to 'Acousticness'.

# %% [markdown]
# #### How does the acousticness score compare between Pop, Hip-Hop/Rap, Dance/Electronic, and Alternative/Indie genres?

# %%
metric = 'Acousticness'
df.groupby("Genre")[metric].mean()[genres].sort_values()
# Out:
# Genre
# Dance/Electronic     0.099440
# Hip-Hop/Rap          0.188741
# Pop                  0.323843
# Alternative/Indie    0.583500
# Name: Acousticness, dtype: float64

# %%
df.describe()
# Out:
#           Energy  Danceability        Key   Loudness  Acousticness  \
# count  50.000000     50.000000  50.000000  50.000000     50.000000
# mean    0.609300      0.716720   5.720000  -6.225900      0.256206
# std     0.154348      0.124975   3.709007   2.349744      0.265250
# min     0.225000      0.351000   0.000000 -14.454000      0.001460
# 25%     0.494000      0.672500   2.000000  -7.552500      0.052800
# 50%     0.597000      0.746000   6.500000  -5.991500      0.188500
# 75%     0.729750      0.794500   8.750000  -4.285500      0.298750
# max     0.855000      0.935000  11.000000  -3.280000      0.934000
#
#        Speechiness  Instrumentalness   Liveness    Valence       Tempo  \
# count    50.000000         50.000000  50.000000  50.000000   50.000000
# mean      0.124158          0.015962   0.196552   0.555710  119.690460
# std       0.116836          0.094312   0.176610   0.216386   25.414778
# min       0.029000          0.000000   0.057400   0.060500   75.801000
# 25%       0.048325          0.000000   0.093950   0.434000   99.557250
# 50%       0.070050          0.000000   0.111000   0.560000  116.969000
# 75%       0.155500          0.000020   0.271250   0.726250  132.317000
# max       0.487000          0.657000   0.792000   0.925000  180.067000
#
#          Duration_ms
# count      50.000000
# mean   199955.360000
# std     33996.122488
# min    140526.000000
# 25%    175845.500000
# 50%    197853.500000
# 75%    215064.000000
# max    312820.000000

# %% [markdown]
# # Provide clear explanations in your notebook. Your explanations should inform the reader what you are trying to achieve, what results you got, and what these results mean.

# %% [markdown]
# ### Provide suggestions about how your analysis can be improved.
# ### Try others values for correlation instead of 0.75,  try 0.7, 0.65.
# ### Pandas have 3 correlation methods (default pearson), so maybe test out others methods of correlation:
# ### kendall : Kendall Tau correlation coefficient
# ### spearman : Spearman rank correlation
